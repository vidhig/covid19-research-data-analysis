# %% [markdown]
# ## Consolidate commercial and non-commerical papers
#
# **Name: Vidhi Gupta (vg5vc)**

# %%
import pandas as pd
import nltk
import numpy as np

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
stoplist = stopwords.words('english') + list(string.punctuation)
stoplist = set(stoplist)

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to /Users/vidhig/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/vidhig/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vidhig/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package tagsets to /Users/vidhig/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
OCHO = ["paper_id","section_num","para_num","sent_num","token_num"]

# %%
comm = pd.read_csv('../dataset/processed-files/commercial.csv')

# %%
non_comm = pd.read_csv('../dataset/processed-files/non_commercial.csv')

# %%
comm
# Out:
#                                        paper_id  \
# 0      5e0c586f047ff909c8ed3fe171c8975a90608d08
# 1      1579fbff7af9b156c6f49fee0526e48f852ea460
# 2      38aa050ad79d8a1d7022c33535255ce9d47914e5
# 3      61722c462b054f36461375e96e502cbf22648c04
# 4      7107f088cbed45d8a06a026276ccf4d602d50f10
# ...                                         ...
# 12873  228650bc0429064d800d4b9c5fb0e00c2533a579
# 12874  2246e28681bde69c65dc9081df367bb661997f19
# 12875  577c6a13f9ef70e9756890fc66e98f537c01ac0a
# 12876  c5c2bc7a07670d6fb970d84a59aab3832752a3f1
# 12877  ba29366173f97f54a22e5c410b3d05e9a9649d28
#
#                                                    title  \
# 0      Neutralizing antibodies against porcine epidem...
# 1      A Recombinant Newcastle Disease Virus (NDV) Ex...
# 2      Potent Inhibition of Junín Virus Infection by ...
# 3      Neutralization of Acidic Intracellular Vesicle...
# 4      Microglia Play a Major Role in Direct Viral-In...
# ...                                                  ...
# 12873  Lipidome profiles of postnatal day 2 vaginal s...
# 12874  Secondary Syphilis in Cali, Colombia: New Conc...
# 12875  Replication and shedding of MERS-CoV in Jamaic...
# 12876  Role of the ERK1/2 Signaling Pathway in the Re...
# 12877  Foodborne Transmission of Deformed Wing Virus ...
#
#                                                     text             journal  \
# 0      BACKGROUND: Porcine epidemic diarrhea virus (P...             Virol J
# 1      Infectious bronchitis virus (IBV) causes a hig...             Sci Rep
# 2      The new world arenavirus Junín virus (JUNV) is...  PLoS Negl Trop Dis
# 3      Dengue fever is one of the most important mosq...             Sci Rep
# 4      Microglia are the resident macrophage-like pop...    Clin Dev Immunol
# ...                                                  ...                 ...
# 12873  The discovery phase identified a total of 1486...            PLoS One
# 12874  A total of 57 patients (age 18–64 years, media...  PLoS Negl Trop Dis
# 12875  The MERS-CoV receptor DPP4 is the main host re...             Sci Rep
# 12876  Clade B New World (NW) arenaviruses, including...             Viruses
# 12877  All the samples from T1 (colonies fed for four...             Insects
#
#        publish_year  is_covid19  section_num  publish_month
# 0              2018       False            0              8
# 1              2018       False            0              8
# 2              2014       False            0              6
# 3              2019       False            0              6
# 4              2013       False            0              6
# ...             ...         ...          ...            ...
# 12873          2019       False            1              9
# 12874          2010       False            1              5
# 12875          2016       False            1              2
# 12876          2018       False            1              4
# 12877          2019       False            1             11
#
# [12878 rows x 8 columns]

# %%
comm['type'] = 'commercial'
comm
# Out:
#                                        paper_id  \
# 0      5e0c586f047ff909c8ed3fe171c8975a90608d08
# 1      1579fbff7af9b156c6f49fee0526e48f852ea460
# 2      38aa050ad79d8a1d7022c33535255ce9d47914e5
# 3      61722c462b054f36461375e96e502cbf22648c04
# 4      7107f088cbed45d8a06a026276ccf4d602d50f10
# ...                                         ...
# 12873  228650bc0429064d800d4b9c5fb0e00c2533a579
# 12874  2246e28681bde69c65dc9081df367bb661997f19
# 12875  577c6a13f9ef70e9756890fc66e98f537c01ac0a
# 12876  c5c2bc7a07670d6fb970d84a59aab3832752a3f1
# 12877  ba29366173f97f54a22e5c410b3d05e9a9649d28
#
#                                                    title  \
# 0      Neutralizing antibodies against porcine epidem...
# 1      A Recombinant Newcastle Disease Virus (NDV) Ex...
# 2      Potent Inhibition of Junín Virus Infection by ...
# 3      Neutralization of Acidic Intracellular Vesicle...
# 4      Microglia Play a Major Role in Direct Viral-In...
# ...                                                  ...
# 12873  Lipidome profiles of postnatal day 2 vaginal s...
# 12874  Secondary Syphilis in Cali, Colombia: New Conc...
# 12875  Replication and shedding of MERS-CoV in Jamaic...
# 12876  Role of the ERK1/2 Signaling Pathway in the Re...
# 12877  Foodborne Transmission of Deformed Wing Virus ...
#
#                                                     text             journal  \
# 0      BACKGROUND: Porcine epidemic diarrhea virus (P...             Virol J
# 1      Infectious bronchitis virus (IBV) causes a hig...             Sci Rep
# 2      The new world arenavirus Junín virus (JUNV) is...  PLoS Negl Trop Dis
# 3      Dengue fever is one of the most important mosq...             Sci Rep
# 4      Microglia are the resident macrophage-like pop...    Clin Dev Immunol
# ...                                                  ...                 ...
# 12873  The discovery phase identified a total of 1486...            PLoS One
# 12874  A total of 57 patients (age 18–64 years, media...  PLoS Negl Trop Dis
# 12875  The MERS-CoV receptor DPP4 is the main host re...             Sci Rep
# 12876  Clade B New World (NW) arenaviruses, including...             Viruses
# 12877  All the samples from T1 (colonies fed for four...             Insects
#
#        publish_year  is_covid19  section_num  publish_month        type
# 0              2018       False            0              8  commercial
# 1              2018       False            0              8  commercial
# 2              2014       False            0              6  commercial
# 3              2019       False            0              6  commercial
# 4              2013       False            0              6  commercial
# ...             ...         ...          ...            ...         ...
# 12873          2019       False            1              9  commercial
# 12874          2010       False            1              5  commercial
# 12875          2016       False            1              2  commercial
# 12876          2018       False            1              4  commercial
# 12877          2019       False            1             11  commercial
#
# [12878 rows x 9 columns]

# %%
non_comm
# Out:
#       is_covid19                          journal  \
# 0          False                             mBio
# 1          False                             mBio
# 2          False              Drug Des Devel Ther
# 3          False                    J Vet Med Sci
# 4          False                 J Korean Med Sci
# ...          ...                              ...
# 1969       False                       Cell Cycle
# 1970       False               Sci China Life Sci
# 1971       False                      J Cell Biol
# 1972       False  Int J Chron Obstruct Pulmon Dis
# 1973       False                             mBio
#
#                                       paper_id  publish_year  section_num  \
# 0     634128ea7d7736750e1c3cd0a48bb37843d06dac          2013            0
# 1     fef0bb9eaac69559d0ff2f92ff83e0affd4435f0          2014            0
# 2     246f59ddffedd4a166b9317dee38bdf6077b2f3f          2014            0
# 3     9cda860c97d430aea207a063d13e8612e023320c          2019            0
# 4     b66704a03a688c4065abff41c4977c4c9939c230          2016            0
# ...                                        ...           ...          ...
# 1969  d00f4dabc58eca254f3b2ca4efafda00d671c3da          2015            1
# 1970  4c3f357d50bfeede5dd0eec81a4b5b7f116c628a          2011            1
# 1971  2ffacfd58f57a95344119c15d27560cdeaea2285          2014            1
# 1972  4c5c841e4ad3fbf9b31d6c0c282dfec035f716bb          2019            1
# 1973  ea5d20e07d05c8b241f90e6429f3daaacc844ecd          2011            1
#
#                                                    text  \
# 0     The majority of emerging zoonoses originate in...
# 1     The broad range and diversity of interferon-st...
# 2     The thiazolidinedione class peroxisome prolife...
# 3     Bovine viral diarrhea (BVD) is a chronic disea...
# 4     Despite the rapidly increasing prevalence of n...
# ...                                                 ...
# 1969  As noted above, a motif based search removes t...
# 1970  We quantified a total of 1109 plasma proteins,...
# 1971  Metaphase-arrested egg extracts from X. laevis...
# 1972  With respect to the exclusion criteria, only 7...
# 1973  To establish the most suitable time points for...
#
#                                                   title  publish_month
# 0     A Strategy To Estimate Unknown Viral Diversity...              9
# 1     Pathogenic Influenza Viruses and Coronaviruses...              5
# 2     Identification of novel multitargeted PPARα/γ/...             11
# 3     Assessment of the cost effectiveness of compul...              3
# 4     Lobeglitazone, a Novel Thiazolidinedione, Impr...             11
# ...                                                 ...            ...
# 1969  Cell cycle control (and more) by programmed −1...              1
# 1970  Plasma biomarker screening for liver fibrosis ...              5
# 1971  The calcium-dependent ribonuclease XendoU prom...             10
# 1972  The association between blood eosinophil perce...              5
# 1973  The Transformation of Enterovirus Replication ...             10
#
# [1974 rows x 8 columns]

# %%
non_comm['type'] = 'non commercial'
non_comm
# Out:
#       is_covid19                          journal  \
# 0          False                             mBio
# 1          False                             mBio
# 2          False              Drug Des Devel Ther
# 3          False                    J Vet Med Sci
# 4          False                 J Korean Med Sci
# ...          ...                              ...
# 1969       False                       Cell Cycle
# 1970       False               Sci China Life Sci
# 1971       False                      J Cell Biol
# 1972       False  Int J Chron Obstruct Pulmon Dis
# 1973       False                             mBio
#
#                                       paper_id  publish_year  section_num  \
# 0     634128ea7d7736750e1c3cd0a48bb37843d06dac          2013            0
# 1     fef0bb9eaac69559d0ff2f92ff83e0affd4435f0          2014            0
# 2     246f59ddffedd4a166b9317dee38bdf6077b2f3f          2014            0
# 3     9cda860c97d430aea207a063d13e8612e023320c          2019            0
# 4     b66704a03a688c4065abff41c4977c4c9939c230          2016            0
# ...                                        ...           ...          ...
# 1969  d00f4dabc58eca254f3b2ca4efafda00d671c3da          2015            1
# 1970  4c3f357d50bfeede5dd0eec81a4b5b7f116c628a          2011            1
# 1971  2ffacfd58f57a95344119c15d27560cdeaea2285          2014            1
# 1972  4c5c841e4ad3fbf9b31d6c0c282dfec035f716bb          2019            1
# 1973  ea5d20e07d05c8b241f90e6429f3daaacc844ecd          2011            1
#
#                                                    text  \
# 0     The majority of emerging zoonoses originate in...
# 1     The broad range and diversity of interferon-st...
# 2     The thiazolidinedione class peroxisome prolife...
# 3     Bovine viral diarrhea (BVD) is a chronic disea...
# 4     Despite the rapidly increasing prevalence of n...
# ...                                                 ...
# 1969  As noted above, a motif based search removes t...
# 1970  We quantified a total of 1109 plasma proteins,...
# 1971  Metaphase-arrested egg extracts from X. laevis...
# 1972  With respect to the exclusion criteria, only 7...
# 1973  To establish the most suitable time points for...
#
#                                                   title  publish_month  \
# 0     A Strategy To Estimate Unknown Viral Diversity...              9
# 1     Pathogenic Influenza Viruses and Coronaviruses...              5
# 2     Identification of novel multitargeted PPARα/γ/...             11
# 3     Assessment of the cost effectiveness of compul...              3
# 4     Lobeglitazone, a Novel Thiazolidinedione, Impr...             11
# ...                                                 ...            ...
# 1969  Cell cycle control (and more) by programmed −1...              1
# 1970  Plasma biomarker screening for liver fibrosis ...              5
# 1971  The calcium-dependent ribonuclease XendoU prom...             10
# 1972  The association between blood eosinophil perce...              5
# 1973  The Transformation of Enterovirus Replication ...             10
#
#                 type
# 0     non commercial
# 1     non commercial
# 2     non commercial
# 3     non commercial
# 4     non commercial
# ...              ...
# 1969  non commercial
# 1970  non commercial
# 1971  non commercial
# 1972  non commercial
# 1973  non commercial
#
# [1974 rows x 9 columns]

# %%
df = pd.concat([comm, non_comm])
# Out:
# /Users/vidhig/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df = df[['paper_id', 'title', 'text', 'journal', 'publish_month', 'publish_year', 'section_num', 'type', 'is_covid19']]
df
# Out:
#                                       paper_id  \
# 0     5e0c586f047ff909c8ed3fe171c8975a90608d08
# 1     1579fbff7af9b156c6f49fee0526e48f852ea460
# 2     38aa050ad79d8a1d7022c33535255ce9d47914e5
# 3     61722c462b054f36461375e96e502cbf22648c04
# 4     7107f088cbed45d8a06a026276ccf4d602d50f10
# ...                                        ...
# 1969  d00f4dabc58eca254f3b2ca4efafda00d671c3da
# 1970  4c3f357d50bfeede5dd0eec81a4b5b7f116c628a
# 1971  2ffacfd58f57a95344119c15d27560cdeaea2285
# 1972  4c5c841e4ad3fbf9b31d6c0c282dfec035f716bb
# 1973  ea5d20e07d05c8b241f90e6429f3daaacc844ecd
#
#                                                   title  \
# 0     Neutralizing antibodies against porcine epidem...
# 1     A Recombinant Newcastle Disease Virus (NDV) Ex...
# 2     Potent Inhibition of Junín Virus Infection by ...
# 3     Neutralization of Acidic Intracellular Vesicle...
# 4     Microglia Play a Major Role in Direct Viral-In...
# ...                                                 ...
# 1969  Cell cycle control (and more) by programmed −1...
# 1970  Plasma biomarker screening for liver fibrosis ...
# 1971  The calcium-dependent ribonuclease XendoU prom...
# 1972  The association between blood eosinophil perce...
# 1973  The Transformation of Enterovirus Replication ...
#
#                                                    text  \
# 0     BACKGROUND: Porcine epidemic diarrhea virus (P...
# 1     Infectious bronchitis virus (IBV) causes a hig...
# 2     The new world arenavirus Junín virus (JUNV) is...
# 3     Dengue fever is one of the most important mosq...
# 4     Microglia are the resident macrophage-like pop...
# ...                                                 ...
# 1969  As noted above, a motif based search removes t...
# 1970  We quantified a total of 1109 plasma proteins,...
# 1971  Metaphase-arrested egg extracts from X. laevis...
# 1972  With respect to the exclusion criteria, only 7...
# 1973  To establish the most suitable time points for...
#
#                               journal  publish_month  publish_year  \
# 0                             Virol J              8          2018
# 1                             Sci Rep              8          2018
# 2                  PLoS Negl Trop Dis              6          2014
# 3                             Sci Rep              6          2019
# 4                    Clin Dev Immunol              6          2013
# ...                               ...            ...           ...
# 1969                       Cell Cycle              1          2015
# 1970               Sci China Life Sci              5          2011
# 1971                      J Cell Biol             10          2014
# 1972  Int J Chron Obstruct Pulmon Dis              5          2019
# 1973                             mBio             10          2011
#
#       section_num            type  is_covid19
# 0               0      commercial       False
# 1               0      commercial       False
# 2               0      commercial       False
# 3               0      commercial       False
# 4               0      commercial       False
# ...           ...             ...         ...
# 1969            1  non commercial       False
# 1970            1  non commercial       False
# 1971            1  non commercial       False
# 1972            1  non commercial       False
# 1973            1  non commercial       False
#
# [14852 rows x 9 columns]

# %%
df.to_csv('../dataset/processed-files/consolidated.csv', index=False)

# %%
len(df['paper_id'].unique().tolist())
# Out:
# 7426

# %%
len(df['section_num'].unique())
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14852 entries, 0 to 1973
# Data columns (total 9 columns):
# paper_id         14852 non-null object
# title            14852 non-null object
# text             14852 non-null object
# journal          14852 non-null object
# publish_month    14852 non-null int64
# publish_year     14852 non-null int64
# section_num      14852 non-null int64
# type             14852 non-null object
# is_covid19       14852 non-null bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 1.0+ MB
